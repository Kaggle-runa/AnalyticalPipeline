# %% [markdown]
# # ホテルキャンセル予約予測分析

# %% [markdown]
# ```
# sample_base_notebook.ipynbは各ソース機能に切り出す前のNotebookの例です。
# 機能をnotebook上に実装する際の参考にしてください。
# "./src"の処理は以下に実装した機能をpythonファイルに切り出したものです。
# ```

# %% [markdown]
# # 機能・ロジックの実装

# %% [markdown]
# ## データ読み込み

# %%
# interface: (data_loader.py)
import pandas as pd

def raw_data_loader(path = "./data/raw/dataset.csv"):

    raw_df = pd.read_csv(path)

    return raw_df

def save_dataset(df, file_path):

    df.to_csv(file_path)

# %%
# interface: (model_loader.py)
import joblib

def save_model(model, file_path):

    joblib.dump(model, file_path)

def load_model(file_path):

    model = joblib.load(file_path)
    
    return model

# %% [markdown]
# ## データ前処理(実装)

# %% [markdown]
# ### 欠損値補間

# %%
# usecase: データの前処理(data_preparation.py)
def complement_repeated_guest_by_median(repeated_guest_col):

    # 対象列の中央値を計算
    fill_value = repeated_guest_col.median()
    completed_col =  repeated_guest_col.fillna(fill_value)

    return completed_col


def complement_children_by_zero(no_of_children_col):

    completed_col =  no_of_children_col.fillna(0)

    return completed_col
    
def complement_required_car_parking_space_by_zero(required_car_parking_space_col):

    completed_col =  required_car_parking_space_col.fillna(0)

    return completed_col

def drop_index(df):

    return df.dropna()

def null_colum_names(df):
    
    count_null = df.isnull().sum()
    null_columuns = count_null[count_null>0].index
    
    return null_columuns

# %% [markdown]
# ### 特徴量生成

# %%
# usecase: データの前処理(data_preparation.py)
def set_one_hot_vector_of(col_name, df):

    feature_df = pd.get_dummies(df, columns=[col_name])

    return feature_df

def calc_total_price(children_col, adults_col, price_par_person_col):
    
    total_proce_col = (children_col + adults_col) * price_par_person_col

    return total_proce_col

# %% [markdown]
# ----

# %% [markdown]
# # 処理の確認

# %%
# パラメータの設定
from src.entities.constants import preprocessed_dir, version, model_dir, date_jst, dataset_path
from src.entities.constants import dataset_path
from src.interfaces.data_loader import raw_data_loader

# 保存先のファイルパス
preprocess_fpath = f"{preprocessed_dir}/preprocessed_dataset_{version}_{date_jst}.csv"
model_fpath =  f"{model_dir}/model_{version}_{date_jst}"

# データ読み込み
raw_df = raw_data_loader(dataset_path)

# %%
raw_df
# Out:
#      no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0               1             0.0                     0                  1
# 1               1             1.0                     1                  0
# 2               2             2.0                     0                  1
# 3               1             0.0                     1                  1
# 4               1             0.0                     0                  1
# ..            ...             ...                   ...                ...
# 995             1             0.0                     1                  3
# 996             1             0.0                     1                  3
# 997             2             1.0                     1                  3
# 998             1             2.0                     0                  2
# 999             1             2.0                     1                  1
#
#         type_of_meal_plan  required_car_parking_space  lead_time  \
# 0    breakfast_and_dinner                         0.0         14
# 1                     NaN                         0.0        107
# 2                  dinner                         0.0         50
# 3                  dinner                         1.0          5
# 4               breakfast                         1.0          5
# ..                    ...                         ...        ...
# 995             breakfast                         0.0         11
# 996             breakfast                         1.0         20
# 997                   NaN                         0.0         50
# 998  breakfast_and_dinner                         0.0         54
# 999  breakfast_and_dinner                         0.0         60
#
#      repeated_guest room_type_reserved  price_per_person  booking_status
# 0               2.0             single            5500.0               1
# 1               1.0             single            5500.0               0
# 2               0.0               twin           20400.0               1
# 3               2.0             single            5500.0               1
# 4               2.0             single            5500.0               0
# ..              ...                ...               ...             ...
# 995             1.0             single            5500.0               1
# 996             1.0             single            5500.0               1
# 997             NaN               twin           17700.0               1
# 998             3.0        deluxe_twin           21300.0               1
# 999             0.0             double           13500.0               1
#
# [1000 rows x 11 columns]

# %% [markdown]
# ## 欠損値補間

# %% [markdown]
# __repeated_guest__

# %%
na_index = raw_df["repeated_guest"].isnull()
raw_df[na_index].head(10)
# Out:
#      no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 35              1             NaN                     1                  2
# 37              2             NaN                     1                  2
# 39              1             NaN                     2                  4
# 51              2             NaN                     0                  1
# 66              1             NaN                     1                  5
# 72              1             1.0                     0                  2
# 80              1             0.0                     1                  2
# 142             2             NaN                     1                  2
# 144             1             NaN                     2                  2
# 148             2             NaN                     0                  1
#
#         type_of_meal_plan  required_car_parking_space  lead_time  \
# 35                 dinner                         NaN         30
# 37                    NaN                         0.0         99
# 39                 dinner                         NaN         36
# 51                 dinner                         1.0          3
# 66              breakfast                         0.0         57
# 72                 dinner                         0.0         45
# 80                    NaN                         1.0         18
# 142             breakfast                         1.0         48
# 144  breakfast_and_dinner                         NaN         33
# 148  breakfast_and_dinner                         NaN         76
#
#      repeated_guest room_type_reserved  price_per_person  booking_status
# 35              NaN               twin               NaN               1
# 37              NaN        deluxe_twin               NaN               1
# 39              NaN             single               NaN               1
# 51              NaN               twin               NaN               1
# 66              NaN             single               NaN               1
# 72              NaN             single            5500.0               1
# 80              NaN        deluxe_twin               NaN               1
# 142             NaN               twin               NaN               1
# 144             NaN               twin               NaN               1
# 148             NaN               twin               NaN               1

# %%
# 欠損補間
raw_df["repeated_guest"] = complement_repeated_guest_by_median(raw_df["repeated_guest"])
# 欠損補間の確認
print(raw_df["repeated_guest"] .isnull().sum())

raw_df[na_index].head(10)
# Out:
# 0
#      no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 35              1             NaN                     1                  2
# 37              2             NaN                     1                  2
# 39              1             NaN                     2                  4
# 51              2             NaN                     0                  1
# 66              1             NaN                     1                  5
# 72              1             1.0                     0                  2
# 80              1             0.0                     1                  2
# 142             2             NaN                     1                  2
# 144             1             NaN                     2                  2
# 148             2             NaN                     0                  1
#
#         type_of_meal_plan  required_car_parking_space  lead_time  \
# 35                 dinner                         NaN         30
# 37                    NaN                         0.0         99
# 39                 dinner                         NaN         36
# 51                 dinner                         1.0          3
# 66              breakfast                         0.0         57
# 72                 dinner                         0.0         45
# 80                    NaN                         1.0         18
# 142             breakfast                         1.0         48
# 144  breakfast_and_dinner                         NaN         33
# 148  breakfast_and_dinner                         NaN         76
#
#      repeated_guest room_type_reserved  price_per_person  booking_status
# 35              1.0               twin               NaN               1
# 37              1.0        deluxe_twin               NaN               1
# 39              1.0             single               NaN               1
# 51              1.0               twin               NaN               1
# 66              1.0             single               NaN               1
# 72              1.0             single            5500.0               1
# 80              1.0        deluxe_twin               NaN               1
# 142             1.0               twin               NaN               1
# 144             1.0               twin               NaN               1
# 148             1.0               twin               NaN               1

# %% [markdown]
# __no_of_children__

# %%
na_index = raw_df["no_of_children"].isnull()
raw_df[na_index].head(10)
# Out:
#      no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 35              1             NaN                     1                  2
# 37              2             NaN                     1                  2
# 39              1             NaN                     2                  4
# 51              2             NaN                     0                  1
# 66              1             NaN                     1                  5
# 142             2             NaN                     1                  2
# 144             1             NaN                     2                  2
# 148             2             NaN                     0                  1
# 153             2             NaN                     0                  2
# 216             2             NaN                     1                  3
#
#         type_of_meal_plan  required_car_parking_space  lead_time  \
# 35                 dinner                         NaN         30
# 37                    NaN                         0.0         99
# 39                 dinner                         NaN         36
# 51                 dinner                         1.0          3
# 66              breakfast                         0.0         57
# 142             breakfast                         1.0         48
# 144  breakfast_and_dinner                         NaN         33
# 148  breakfast_and_dinner                         NaN         76
# 153  breakfast_and_dinner                         0.0         24
# 216             breakfast                         NaN         60
#
#      repeated_guest room_type_reserved  price_per_person  booking_status
# 35              1.0               twin               NaN               1
# 37              1.0        deluxe_twin               NaN               1
# 39              1.0             single               NaN               1
# 51              1.0               twin               NaN               1
# 66              1.0             single               NaN               1
# 142             1.0               twin               NaN               1
# 144             1.0               twin               NaN               1
# 148             1.0               twin               NaN               1
# 153             1.0        deluxe_twin               NaN               1
# 216             1.0               twin               NaN               1

# %%
# no_of_children
raw_df["no_of_children"] =  complement_children_by_zero(raw_df["no_of_children"])

# 欠損補間の確認
raw_df["repeated_guest"] .isnull().sum()
raw_df[na_index].head(10)
# Out:
#      no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 35              1             0.0                     1                  2
# 37              2             0.0                     1                  2
# 39              1             0.0                     2                  4
# 51              2             0.0                     0                  1
# 66              1             0.0                     1                  5
# 142             2             0.0                     1                  2
# 144             1             0.0                     2                  2
# 148             2             0.0                     0                  1
# 153             2             0.0                     0                  2
# 216             2             0.0                     1                  3
#
#         type_of_meal_plan  required_car_parking_space  lead_time  \
# 35                 dinner                         NaN         30
# 37                    NaN                         0.0         99
# 39                 dinner                         NaN         36
# 51                 dinner                         1.0          3
# 66              breakfast                         0.0         57
# 142             breakfast                         1.0         48
# 144  breakfast_and_dinner                         NaN         33
# 148  breakfast_and_dinner                         NaN         76
# 153  breakfast_and_dinner                         0.0         24
# 216             breakfast                         NaN         60
#
#      repeated_guest room_type_reserved  price_per_person  booking_status
# 35              1.0               twin               NaN               1
# 37              1.0        deluxe_twin               NaN               1
# 39              1.0             single               NaN               1
# 51              1.0               twin               NaN               1
# 66              1.0             single               NaN               1
# 142             1.0               twin               NaN               1
# 144             1.0               twin               NaN               1
# 148             1.0               twin               NaN               1
# 153             1.0        deluxe_twin               NaN               1
# 216             1.0               twin               NaN               1

# %% [markdown]
# __required_car_parking_space__

# %%
na_index = raw_df["required_car_parking_space"].isnull()
raw_df[na_index].head(10)
# Out:
#      no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 35              1             0.0                     1                  2
# 39              1             0.0                     2                  4
# 144             1             0.0                     2                  2
# 148             2             0.0                     0                  1
# 216             2             0.0                     1                  3
# 267             4             0.0                     1                  2
# 272             2             0.0                     1                  3
# 305             1             0.0                     4                  2
# 312             1             0.0                     1                  1
# 384             2             0.0                     0                  2
#
#         type_of_meal_plan  required_car_parking_space  lead_time  \
# 35                 dinner                         NaN         30
# 39                 dinner                         NaN         36
# 144  breakfast_and_dinner                         NaN         33
# 148  breakfast_and_dinner                         NaN         76
# 216             breakfast                         NaN         60
# 267             breakfast                         NaN         13
# 272                   NaN                         NaN         32
# 305  breakfast_and_dinner                         NaN         42
# 312  breakfast_and_dinner                         NaN          8
# 384  breakfast_and_dinner                         NaN          7
#
#      repeated_guest room_type_reserved  price_per_person  booking_status
# 35              1.0               twin               NaN               1
# 39              1.0             single               NaN               1
# 144             1.0               twin               NaN               1
# 148             1.0               twin               NaN               1
# 216             1.0               twin               NaN               1
# 267             1.0             family               NaN               1
# 272             1.0               twin               NaN               1
# 305             1.0             single               NaN               1
# 312             1.0             single               NaN               1
# 384             1.0               twin               NaN               1

# %%
# required_car_parking_space
raw_df["required_car_parking_space"] =  complement_required_car_parking_space_by_zero(raw_df["required_car_parking_space"])

# 欠損補間の確認
raw_df["repeated_guest"] .isnull().sum()
raw_df[na_index].head(10)
# Out:
#      no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 35              1             0.0                     1                  2
# 39              1             0.0                     2                  4
# 144             1             0.0                     2                  2
# 148             2             0.0                     0                  1
# 216             2             0.0                     1                  3
# 267             4             0.0                     1                  2
# 272             2             0.0                     1                  3
# 305             1             0.0                     4                  2
# 312             1             0.0                     1                  1
# 384             2             0.0                     0                  2
#
#         type_of_meal_plan  required_car_parking_space  lead_time  \
# 35                 dinner                         0.0         30
# 39                 dinner                         0.0         36
# 144  breakfast_and_dinner                         0.0         33
# 148  breakfast_and_dinner                         0.0         76
# 216             breakfast                         0.0         60
# 267             breakfast                         0.0         13
# 272                   NaN                         0.0         32
# 305  breakfast_and_dinner                         0.0         42
# 312  breakfast_and_dinner                         0.0          8
# 384  breakfast_and_dinner                         0.0          7
#
#      repeated_guest room_type_reserved  price_per_person  booking_status
# 35              1.0               twin               NaN               1
# 39              1.0             single               NaN               1
# 144             1.0               twin               NaN               1
# 148             1.0               twin               NaN               1
# 216             1.0               twin               NaN               1
# 267             1.0             family               NaN               1
# 272             1.0               twin               NaN               1
# 305             1.0             single               NaN               1
# 312             1.0             single               NaN               1
# 384             1.0               twin               NaN               1

# %% [markdown]
# __その他の欠損を削除__

# %%
raw_df.isnull().sum()
# Out:
# no_of_adults                    0
# no_of_children                  0
# no_of_weekend_nights            0
# no_of_week_nights               0
# type_of_meal_plan             205
# required_car_parking_space      0
# lead_time                       0
# repeated_guest                  0
# room_type_reserved              0
# price_per_person               70
# booking_status                  0
# dtype: int64

# %%
# 欠損カラムを削除
completed_df =  drop_index(raw_df)

completed_df.isnull().sum()
# Out:
# no_of_adults                  0
# no_of_children                0
# no_of_weekend_nights          0
# no_of_week_nights             0
# type_of_meal_plan             0
# required_car_parking_space    0
# lead_time                     0
# repeated_guest                0
# room_type_reserved            0
# price_per_person              0
# booking_status                0
# dtype: int64

# %% [markdown]
# ## 特徴量生成

# %% [markdown]
# __type_of_meal_plan__

# %%
preproc_df = set_one_hot_vector_of("type_of_meal_plan", completed_df)

preproc_df
# Out:
#      no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0               1             0.0                     0                  1
# 2               2             2.0                     0                  1
# 3               1             0.0                     1                  1
# 4               1             0.0                     0                  1
# 5               1             0.0                     1                  1
# ..            ...             ...                   ...                ...
# 994             1             0.0                     0                  0
# 995             1             0.0                     1                  3
# 996             1             0.0                     1                  3
# 998             1             2.0                     0                  2
# 999             1             2.0                     1                  1
#
#      required_car_parking_space  lead_time  repeated_guest room_type_reserved  \
# 0                           0.0         14             2.0             single
# 2                           0.0         50             0.0               twin
# 3                           1.0          5             2.0             single
# 4                           1.0          5             2.0             single
# 5                           0.0         21             6.0             single
# ..                          ...        ...             ...                ...
# 994                         0.0         52             1.0             single
# 995                         0.0         11             1.0             single
# 996                         1.0         20             1.0             single
# 998                         0.0         54             3.0        deluxe_twin
# 999                         0.0         60             0.0             double
#
#      price_per_person  booking_status  type_of_meal_plan_breakfast  \
# 0              5500.0               1                        False
# 2             20400.0               1                        False
# 3              5500.0               1                        False
# 4              5500.0               0                         True
# 5              5500.0               0                        False
# ..                ...             ...                          ...
# 994            5500.0               1                         True
# 995            5500.0               1                         True
# 996            5500.0               1                         True
# 998           21300.0               1                        False
# 999           13500.0               1                        False
#
#      type_of_meal_plan_breakfast_and_dinner  type_of_meal_plan_dinner
# 0                                      True                     False
# 2                                     False                      True
# 3                                     False                      True
# 4                                     False                     False
# 5                                      True                     False
# ..                                      ...                       ...
# 994                                   False                     False
# 995                                   False                     False
# 996                                   False                     False
# 998                                    True                     False
# 999                                    True                     False
#
# [739 rows x 13 columns]

# %% [markdown]
# __room_type_reserved__

# %%
preproc_df = set_one_hot_vector_of("room_type_reserved", preproc_df)
preproc_df

# %% [markdown]
# __total_price__

# %%
preproc_df["total_price"] = calc_total_price(completed_df["no_of_children"], completed_df["no_of_adults"], completed_df["price_per_person"])

preproc_df
# Out:
#      no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0               1             0.0                     0                  1
# 2               2             2.0                     0                  1
# 3               1             0.0                     1                  1
# 4               1             0.0                     0                  1
# 5               1             0.0                     1                  1
# ..            ...             ...                   ...                ...
# 994             1             0.0                     0                  0
# 995             1             0.0                     1                  3
# 996             1             0.0                     1                  3
# 998             1             2.0                     0                  2
# 999             1             2.0                     1                  1
#
#      required_car_parking_space  lead_time  repeated_guest  price_per_person  \
# 0                           0.0         14             2.0            5500.0
# 2                           0.0         50             0.0           20400.0
# 3                           1.0          5             2.0            5500.0
# 4                           1.0          5             2.0            5500.0
# 5                           0.0         21             6.0            5500.0
# ..                          ...        ...             ...               ...
# 994                         0.0         52             1.0            5500.0
# 995                         0.0         11             1.0            5500.0
# 996                         1.0         20             1.0            5500.0
# 998                         0.0         54             3.0           21300.0
# 999                         0.0         60             0.0           13500.0
#
#      booking_status  type_of_meal_plan_breakfast  \
# 0                 1                        False
# 2                 1                        False
# 3                 1                        False
# 4                 0                         True
# 5                 0                        False
# ..              ...                          ...
# 994               1                         True
# 995               1                         True
# 996               1                         True
# 998               1                        False
# 999               1                        False
#
#      type_of_meal_plan_breakfast_and_dinner  type_of_meal_plan_dinner  \
# 0                                      True                     False
# 2                                     False                      True
# 3                                     False                      True
# 4                                     False                     False
# 5                                      True                     False
# ..                                      ...                       ...
# 994                                   False                     False
# 995                                   False                     False
# 996                                   False                     False
# 998                                    True                     False
# 999                                    True                     False
#
#      room_type_reserved_deluxe_twin  room_type_reserved_double  \
# 0                             False                      False
# 2                             False                      False
# 3                             False                      False
# 4                             False                      False
# 5                             False                      False
# ..                              ...                        ...
# 994                           False                      False
# 995                           False                      False
# 996                           False                      False
# 998                            True                      False
# 999                           False                       True
#
#      room_type_reserved_family  room_type_reserved_single  \
# 0                        False                       True
# 2                        False                      False
# 3                        False                       True
# 4                        False                       True
# 5                        False                       True
# ..                         ...                        ...
# 994                      False                       True
# 995                      False                       True
# 996                      False                       True
# 998                      False                      False
# 999                      False                      False
#
#      room_type_reserved_twin  total_price
# 0                      False       5500.0
# 2                       True      81600.0
# 3                      False       5500.0
# 4                      False       5500.0
# 5                      False       5500.0
# ..                       ...          ...
# 994                    False       5500.0
# 995                    False       5500.0
# 996                    False       5500.0
# 998                    False      63900.0
# 999                    False      40500.0
#
# [739 rows x 18 columns]
